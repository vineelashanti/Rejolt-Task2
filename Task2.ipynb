# %%
# !pip install bs4
# !pip install requests
# !pip install html5lib
# Out:
# Requirement already satisfied: bs4 in c:\users\chitti\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\chitti\anaconda3\lib\site-packages (from bs4) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\chitti\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.4)
# Requirement already satisfied: requests in c:\users\chitti\anaconda3\lib\site-packages (2.29.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chitti\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chitti\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\chitti\anaconda3\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chitti\anaconda3\lib\site-packages (from requests) (2023.5.7)
# Requirement already satisfied: html5lib in c:\users\chitti\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\users\chitti\anaconda3\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\chitti\anaconda3\lib\site-packages (from html5lib) (0.5.1)

# %%
def getNextPage(soup):
  page=soup.find()

# %%
import requests
from bs4 import BeautifulSoup
url="https://www.flipkart.com/search?q=tv+smart+tv&as=on&as-show=on&otracker=AS_Query_PredictiveAutoSuggest_6_0_na_na_na&otracker1=AS_Query_PredictiveAutoSuggest_6_0_na_na_na&as-pos=6&as-type=PREDICTIVE&suggestionId=tv+smart+tv&requestId=1541c2ff-4568-4b08-8920-a296a963fe57"
r=requests.get(url)
htmlContent=r.content
soup=BeautifulSoup(htmlContent,'html.parser')
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html><head><title>Online Shopping India Mobile, Cameras, Lifestyle &amp; more Online @ Flipkart.com</title><meta content="IE=edge" http-equiv="X-UA-Compatible"/><style>html,
#         body {
#             font-family: Roboto, arial, tahoma, verdana, sans-serif;
#             height: 100%;
#             margin: 0;
#         }
#
#         .btn {
#             border-radius: 4px;
#             margin-top: 16px;
#             display: inline-block;
#             color: #fff;
#             font-family: inter_semi_bold, Arial, sans-serif;
#             border: none;
#             font-size: inherit;
#             cursor: pointer;
#             width: 328px;
#             height: 40px;
#         }
#
#         .disable_btn {
#             background-color: #808080;
#             cursor: not-allowed;
#         }
#
#         #retry_btn {
#             background-color: #2A55E5;
#             display: none;
#         }</style></head><body><div style="background-color:#2874f0;height:78px;text-align:center;"><div style="width: 978px;margin: 0 auto;padding-top: 2px;text-align:left;"><div style="margin-top: 15px; text-align: center"><img src="http://img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" style="border: none;" width="149"/></div></div></div><div style="text-align: center; font-size: 14px; padding: 20px; position: absolute;left: 50%; top: 50%; transform: translate(-50%, -50%);"><div><img alt="" id="IMG_3" src="https://rukminim2.flixcart.com/www/444/333/promos/28/09/2023/735e2a1e-ab96-41c2-b875-56c25c233a29.png?q=100"/><div style="font-size: 20px; margin-top: 30px; font-weight: 600;">Lot of rush for the best offers!</div><div style="font-size: 17px;  margin-top: 10px; color: #666666;">We're finding the best way to get you there faster.</div></div><button class="btn disable_btn" id="timer_text">Retry in 10 sec</button> <button class="btn" id="retry_btn" type="button">Try now</button></div><script nonce="12532125392048822220">let seconds = 10;
#         const timerText = document.getElementById("timer_text")
#         const retryBtn = document.getElementById("retry_btn")
#         // Update the count down every 1 second
#         var timerId = setInterval(function () {
#             timerText.innerHTML = `Retry in ${seconds--} sec`;
#             if (seconds < 0) {
#                 clearInterval(timerId);
#                 timerText.remove()
#                 retryBtn.style.display = "inline"
#             }
#         }, 1000);
#         retryBtn.addEventListener('click', function () { window.location.reload() })</script></body></html>>

# %%
names=[]
price=[]
rating=[]
ram=[]
memory=[]
camera=[]
screen=[]
for k in range(1,38):
  url="https://www.flipkart.com/search?q=tv+smart+tv&as=on&as-show=on&otracker=AS_Query_PredictiveAutoSuggest_6_0_na_na_na&otracker1=AS_Query_PredictiveAutoSuggest_6_0_na_na_na&as-pos=6&as-type=PREDICTIVE&suggestionId=tv+smart+tv&requestId=1541c2ff-4568-4b08-8920-a296a963fe57"
  r=requests.get(url)
  htmlContent=r.content
  soup=BeautifulSoup(htmlContent,'html.parser')
  for a in soup.find_all('a',class_="_1fQZEK"):
    t=[]
    for i in a.find_all("li",class_='rgWa7D'):
      t.append(i.get_text())
    memory.append(t[0])
    screen.append(t[1])
    camera.append(t[2])
    try:
      names.append(a.find('div',class_="_4rR01T").get_text())
    except:
      names.append("Nan")
    try:
      price.append(a.find('div',class_="_30jeq3 _1_WHN1").get_text())
    except:
      price.append("Nan")
    try:
      rating.append(a.find('div',class_="_3LWZlK").get_text())
    except:
      rating.append("Nan")
data={"Name":names,"Price":price,"Rating":rating,"Memory":memory,"Camera":camera,"Screen":screen}
import pandas as pd
df=pd.DataFrame(data)
df.head()
# Out:
#                                                 Name    Price Rating  \
# 0  Acer Advanced I Series 108 cm (43 inch) Ultra ...  ₹22,999    4.3
# 1  BeethoSOL 80 cm (32 inch) HD Ready LED Smart A...   ₹6,999    4.1
# 2  iFFALCON by TCL 80 cm (32 inch) HD Ready LED S...   ₹8,999    4.2
# 3  iFFALCON by TCL U62 108 cm (43 inch) Ultra HD ...  ₹17,999    4.2
# 4  SAMSUNG 80 cm (32 Inch) HD Ready LED Smart Tiz...  ₹13,990    4.3
#
#                             Memory             Camera  \
# 0      Operating System: Google TV  Launch Year: 2023
# 1  Operating System: Android Based  Launch Year: 2023
# 2        Operating System: Android  Launch Year: 2023
# 3      Operating System: Google TV  Launch Year: 2022
# 4          Operating System: Tizen  Launch Year: 2022
#
#                              Screen
# 0  Ultra HD (4K) 3840 x 2160 Pixels
# 1        HD Ready 1366 x 768 Pixels
# 2        HD Ready 1366 x 768 Pixels
# 3  Ultra HD (4K) 3840 x 2160 Pixels
# 4        HD Ready 1366 x 768 Pixels
